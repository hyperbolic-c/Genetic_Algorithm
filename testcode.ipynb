# %%
# ! pip install datetime
import datetime
now_time = datetime.datetime.now()
# print(now_time)
# Out:
# 2022-04-02 13:24:33.537311

# %%
import numpy as np
rval = np.random.rand()
if rval < 0.33:
    print('2')
elif 0.33 < rval < 0.66:
    print('3')
else:
    print('4')
# Out:
# 2

# %%
a = [{'b':[1, 2]}, {'c':[3, 4]}]
# a['b'] = [-a['b'][0], a['b'][1]]
# print(a)
print(len(a))
# Out:
# 2

# %%
quadlist = [{'g3': 53, 'g4': 52, 'g12': 4, 'g13': 3, 'g17': 6, 'gp0': 1,
             'gp5': 1, 'gp6': 1, 'gp7': 1, 'gp12': 1, 'gp17': 1, 'gp18': 1},
            {'g2': 65, 'g6': 6, 'g7': 6, 'g9': 2, 'g10': 6, 'g11': 7, 'g18': 3,
             'g22': 3, 'g27': 6, 'g28': 7, 'g29': 4, 'g30': 3, 'gp2': 1, 'gp3': 1,
             'gp8': 1, 'gp15': 1, 'gp16': 1, 'gp21': 1},
            {'g0': 65, 'g1': 53, 'g26': 3, 'gp9': 1, 'gp10': 1, 'gp14': 1, 'gp19': 1, 'gp20': 1},
            {'g5': 64, 'g8': 6, 'g14': 1, 'g15': 6, 'g16': 6, 'g19': 6, 'g20': 7,
             'g21': 4, 'g23': 6, 'g24': 6, 'g25': 6, 'gp1': 1, 'gp4': 1, 'gp11': 1, 'gp13': 1}]

# %%
import datetime
filename = "result.res"
f = open(filename,'a')
def writeResTxt(quadlist):
    """
    将结果写进txt文件
    """
    f.write('\n')
    now_time = datetime.datetime.now()
    f.write('- - -This result is at ' + str(now_time) + '- - -')
    f.write('\n')
    nosFPGA = len(quadlist)
    # print(nosFPGA)
    for fpga in range(nosFPGA):
        f.write("F"+str(fpga))
        # for dict in quadlist:
            # print('F0:' + str(list(quadlist[0].keys())))
        dict = quadlist[fpga]
        f.write(" " + str(list(dict.keys())))
        f.write("\n")

# %%
writeResTxt(quadlist)

# %%
pop = -1 + 2 * np.random.random((100, 53 * 2))
nodelist = [['g8', 'gp2', 'g10', 'g11', 'g13'], ['g7', 'gp3', 'g10', 'g11'],
            ['g6', 'gp4', 'g11'], ['g14', 'gp5', 'g1', 'g18'], ['g5', 'gp6'],
            ['g5', 'gp7'], ['g17', 'gp8', 'g19', 'g20', 'g22'],
            ['g16', 'gp9', 'g19', 'g20'], ['g15', 'gp10','g20'], ['g0', 'gp11'],
            ['g0', 'gp12'], ['g0', 'gp13'], ['g2', 'gp14'], ['g2', 'gp15'],
            ['g2', 'gp16'], ['g25', 'gp17', 'g27', 'g28', 'g30'],
            ['g24', 'gp18', 'g27', 'g28'], ['g23', 'gp19', 'g28'],
            ['gp20', 'g10', 'g5', 'g19', 'g0', 'g2', 'g27', 'g11', 'g12', 'g20', 'g21', 'g28', 'g29'],
            ['gp21', 'g10', 'g5', 'g19', 'g0', 'g2', 'g27', 'g11', 'g12', 'g20', 'g21', 'g28', 'g29'],
            ['gp0', 'g4', 'g5', 'g1', 'g0', 'g2', 'g3'],
            ['gp1', 'g5', 'g0', 'g2', 'g3', 'g26'], ['g4', 'g6', 'g7', 'g8'],
            ['g11', 'g6'], ['g9', 'g6', 'g7', 'g8'], ['g12', 'g6', 'g7', 'g8'],
            ['g10', 'g7'], ['g13', 'g8'], ['g1', 'g15', 'g16', 'g17'],
            ['g20', 'g15'], ['g18', 'g15', 'g16', 'g17'],
            ['g21', 'g15', 'g16', 'g17'], ['g19', 'g16'], ['g22', 'g17'],
            ['g3', 'g23', 'g24', 'g25'], ['g28', 'g23'],
            ['g26', 'g23', 'g24', 'g25'], ['g29', 'g23', 'g24', 'g25'],
            ['g27', 'g24'], ['g30', 'g25']]
expdict = {
    'g0': 65,
    'g1': 53,
    'g2': 65,
    'g3': 53,
    'g4': 52,
    'g5': 64,
    'g6': 6,
    'g7': 6,
    'g8': 6,
    'g9': 2,
    'g10': 6,
    'g11': 7,
    'g12': 4,
    'g13': 3,
    'g14': 1,
    'g15': 6,
    'g16': 6,
    'g17': 6,
    'g18': 3,
    'g19': 6,
    'g20': 7,
    'g21': 4,
    'g22': 3,
    'g23': 6,
    'g24': 6,
    'g25': 6,
    'g26': 3,
    'g27': 6,
    'g28': 7,
    'g29': 4,
    'g30': 3,
    'gp0': 1,
    'gp1': 1,
    'gp2': 1,
    'gp3': 1,
    'gp4': 1,
    'gp5': 1,
    'gp6': 1,
    'gp7': 1,
    'gp8': 1,
    'gp9': 1,
    'gp10': 1,
    'gp11': 1,
    'gp12': 1,
    'gp13': 1,
    'gp14': 1,
    'gp15': 1,
    'gp16': 1,
    'gp17': 1,
    'gp18': 1,
    'gp19': 1,
    'gp20': 1,
    'gp21': 1
}

# %%
# from allocation import Node
class Node(object):
    """
    输入字典{'name':g0, 'weight':1, 'coord':[0.1, 0.2]}
    实例化之后[{'name':g0, 'weight':1, 'coord':[0.1, 0.2]},
              {'name':g1, 'weight':2, 'coord':[0.2, 0.2]]
              type = <class 'allocation.Node'>
    exp_node = Node(**exp_dict)
    """

    def __init__(self, **dict):
        self.__dict__.update(dict)
    
    def todone(self):
        print('done')
    
    def quad(self):
        x = self.coord[0]
        y = self.coord[1]
        if x > 0 and y > 0:
            self.rant = 1
            # self.
        elif x > 0 and y < 0:
            self.rant = 4  
        elif x < 0 and y > 0:
            self.rant = 2
        else:
            self.rant = 3

    # def node_quad(self):

# %%
# from allocation import Node
def geneCoord(pop):
    """
    将节点的所有信息汇总到一个字典
    返回pop中所有gene对应的节点信息
    allgene = [[{'name': 'g0', 'weight': 65, 'coord':[0.1, 0.2]}, {...], [{...]]
    """
    N, nc = np.shape(pop)
    n = int(nc / 2)
    # aredict = Initpre.read_are(arepath)
    aredict = expdict
    allgene = []
    for i in range(N):
        allnode = []
        gene = pop[i, :]
        # allnode = cls().geneDict(gene, aredict)
        j = 0
        for key, item in aredict.items():
            pos = {}
            pos['name'] = key
            pos['weight'] = item
            pos['coord'] = [gene[j], gene[j + n]]
            pos['rant'] = 0
            allnode.append(pos)
            j += 1
        allgene.append(allnode)
    # print(allgene)
    return allgene

# %%
allgene = geneCoord(pop)
print(len(allgene))
# Out:
# 100

# %%
gene_exp = [{
    'name': 'g0',
    'weight': 65,
    'coord': [0.5914133293211394, -0.7508134254694858],
    'rant': 0
}, {
    'name': 'g1',
    'weight': 53,
    'coord': [-0.05583040419619967, 0.588065055547561],
    'rant': 0
}, {
    'name': 'g2',
    'weight': 65,
    'coord': [-0.02539711719621396, -0.5281763799676933],
    'rant': 0
}, {
    'name': 'g3',
    'weight': 53,
    'coord': [-0.22432976434195795, -0.4981991071369003],
    'rant': 0
}, {
    'name': 'g4',
    'weight': 52,
    'coord': [-0.8535034768052483, -0.8850894312179902],
    'rant': 0
}, {
    'name': 'g5',
    'weight': 64,
    'coord': [-0.2089956346182853, 0.5870773048519937],
    'rant': 0
}, {
    'name': 'g6',
    'weight': 6,
    'coord': [0.1586837304365898, 0.808232250814408],
    'rant': 0
}, {
    'name': 'g7',
    'weight': 6,
    'coord': [-0.15942995396416193, -0.03811137200722903],
    'rant': 0
}, {
    'name': 'g8',
    'weight': 6,
    'coord': [0.5969020940308603, 0.7696552426466805],
    'rant': 0
}, {
    'name': 'g9',
    'weight': 2,
    'coord': [-0.7961941251670779, -0.16552554777749107],
    'rant': 0
}, {
    'name': 'g10',
    'weight': 6,
    'coord': [-0.4360297839663616, -0.19806989583900658],
    'rant': 0
}, {
    'name': 'g11',
    'weight': 7,
    'coord': [-0.6223902433390824, 0.521276485700533],
    'rant': 0
}, {
    'name': 'g12',
    'weight': 4,
    'coord': [0.28715713492475325, -0.05057771358246366],
    'rant': 0
}, {
    'name': 'g13',
    'weight': 3,
    'coord': [0.5450982253111067, -0.0003710703914674429],
    'rant': 0
}, {
    'name': 'g14',
    'weight': 1,
    'coord': [-0.9633129838180488, 0.3696480504845512],
    'rant': 0
}, {
    'name': 'g15',
    'weight': 6,
    'coord': [-0.9595361354309833, -0.19875117148345622],
    'rant': 0
}, {
    'name': 'g16',
    'weight': 6,
    'coord': [-0.04133266880496511, 0.7696137874851687],
    'rant': 0
}, {
    'name': 'g17',
    'weight': 6,
    'coord': [-0.2595041385164538, -0.37909508094952393],
    'rant': 0
}, {
    'name': 'g18',
    'weight': 3,
    'coord': [-0.17451716998023858, 0.9074624603593442],
    'rant': 0
}, {
    'name': 'g19',
    'weight': 6,
    'coord': [-0.808664919280458, -0.7855218555891115],
    'rant': 0
}, {
    'name': 'g20',
    'weight': 7,
    'coord': [0.9221657321169583, -0.016911617189688366],
    'rant': 0
}, {
    'name': 'g21',
    'weight': 4,
    'coord': [-0.7544658470818602, -0.2125385810163678],
    'rant': 0
}, {
    'name': 'g22',
    'weight': 3,
    'coord': [0.6799525425567876, 0.41103631667375895],
    'rant': 0
}, {
    'name': 'g23',
    'weight': 6,
    'coord': [-0.9137995588605514, 0.1145196392734642],
    'rant': 0
}, {
    'name': 'g24',
    'weight': 6,
    'coord': [-0.25979657959852176, 0.5322168406028014],
    'rant': 0
}, {
    'name': 'g25',
    'weight': 6,
    'coord': [0.3238627366822997, 0.9180701292709994],
    'rant': 0
}, {
    'name': 'g26',
    'weight': 3,
    'coord': [0.8435635839012996, 0.4729704556118661],
    'rant': 0
}, {
    'name': 'g27',
    'weight': 6,
    'coord': [-0.6161851921610679, -0.07331239907541143],
    'rant': 0
}, {
    'name': 'g28',
    'weight': 7,
    'coord': [0.3210606259470865, 0.7531429124522053],
    'rant': 0
}, {
    'name': 'g29',
    'weight': 4,
    'coord': [-0.45870596804808317, 0.8600655319454023],
    'rant': 0
}, {
    'name': 'g30',
    'weight': 3,
    'coord': [0.8377393920517027, -0.31019463590631435],
    'rant': 0
}, {
    'name': 'gp0',
    'weight': 1,
    'coord': [0.8988341547384899, 0.6623060050693861],
    'rant': 0
}, {
    'name': 'gp1',
    'weight': 1,
    'coord': [0.6643339001206705, 0.1706807397577963],
    'rant': 0
}, {
    'name': 'gp2',
    'weight': 1,
    'coord': [-0.009032348120521005, -0.612051551318519],
    'rant': 0
}, {
    'name': 'gp3',
    'weight': 1,
    'coord': [0.793971875295084, 0.03632556938152165],
    'rant': 0
}, {
    'name': 'gp4',
    'weight': 1,
    'coord': [-0.9271422732827854, -0.5344132467290663],
    'rant': 0
}, {
    'name': 'gp5',
    'weight': 1,
    'coord': [0.4062613724450608, 0.8689779677511607],
    'rant': 0
}, {
    'name': 'gp6',
    'weight': 1,
    'coord': [-0.7941860654527497, -0.0981831888575766],
    'rant': 0
}, {
    'name': 'gp7',
    'weight': 1,
    'coord': [-0.16479691518383, 0.689770523044712],
    'rant': 0
}, {
    'name': 'gp8',
    'weight': 1,
    'coord': [0.2316222624242068, -0.9151712768853069],
    'rant': 0
}, {
    'name': 'gp9',
    'weight': 1,
    'coord': [0.08701239524854776, 0.7495556055214792],
    'rant': 0
}, {
    'name': 'gp10',
    'weight': 1,
    'coord': [-0.6233038528974215, 0.9092938598680687],
    'rant': 0
}, {
    'name': 'gp11',
    'weight': 1,
    'coord': [0.4597436497231211, -0.06796758514057877],
    'rant': 0
}, {
    'name': 'gp12',
    'weight': 1,
    'coord': [-0.525956047639333, -0.8605683254210219],
    'rant': 0
}, {
    'name': 'gp13',
    'weight': 1,
    'coord': [-0.20773717100742606, 0.13987438260316254],
    'rant': 0
}, {
    'name': 'gp14',
    'weight': 1,
    'coord': [-0.40407053194578246, -0.4690713513667393],
    'rant': 0
}, {
    'name': 'gp15',
    'weight': 1,
    'coord': [-0.5357378406193067, -0.3881765867987117],
    'rant': 0
}, {
    'name': 'gp16',
    'weight': 1,
    'coord': [0.8723077244502109, -0.4650443948427776],
    'rant': 0
}, {
    'name': 'gp17',
    'weight': 1,
    'coord': [0.6709401954441185, -0.7846311751311268],
    'rant': 0
}, {
    'name': 'gp18',
    'weight': 1,
    'coord': [0.6403146971175169, 0.8302447352781188],
    'rant': 0
}, {
    'name': 'gp19',
    'weight': 1,
    'coord': [-0.9047871391088005, -0.777096555007063],
    'rant': 0
}, {
    'name': 'gp20',
    'weight': 1,
    'coord': [-0.43270555062776306, 0.8259667276788984],
    'rant': 0
}, {
    'name': 'gp21',
    'weight': 1,
    'coord': [0.2143031198599945, 0.6313769149632662],
    'rant': 0
}]
# from allocation import Node

node_exp = []
for dict in gene_exp:
    n_exp = Node(**dict)
    n_exp.quad()
    node_exp.append(n_exp)
# node_exp[0].quad()
print(node_exp[1].rant)
# Out:
# 2

# %%
# def calQuad(node_exp):
#     Z1, Z2, Z3, Z4 =[], [], [], []
#     for node in node_exp:
#         if node.rant == 1:
#             Z1.append(node.name)
#         if node.rant == 2:
#             Z2.append(node.name)
#         if node.rant == 3:
#             Z3.append(node.name)
#         if node.rant == 4:
#             Z4.append(node.name)
#     # Z1 = set(Z1)
#     return [set(Z1), set(Z2), set(Z3), set(Z4)]
def calQuad(gene_exp):
    Z1, Z2, Z3, Z4 = [], [], [], []
    for node_exp in gene_exp:
        if node_exp.rant == 1:
            Z1.append(node_exp)
        if node_exp.rant == 2:
            Z2.append(node_exp)
        if node_exp.rant == 3:
            Z3.append(node_exp)
        if node_exp.rant == 4:
            Z4.append(node_exp)
            # print(node_exp)
    # print([Z1, Z2, Z3, Z4])
    return [Z1, Z2, Z3, Z4]

# %%
b = calQuad(node_exp)
# print(b)
s_list = []
for i in b:
    n_list = []
    for exp in i:
        n_list.append(exp.name)
    s_list.append(set(n_list))
print(s_list)
# Out:
# [{'g6', 'g8', 'g22', 'gp21', 'gp3', 'gp0', 'gp18', 'g28', 'gp1', 'gp5', 'g25', 'gp9', 'g26'}, {'g11', 'g23', 'g16', 'g1', 'g5', 'gp20', 'g18', 'gp7', 'gp10', 'gp13', 'g24', 'g14', 'g29'}, {'gp12', 'g2', 'g9', 'g21', 'g3', 'g10', 'g17', 'gp14', 'g7', 'gp15', 'g27', 'gp19', 'gp2', 'gp6', 'g19', 'g4', 'gp4', 'g15'}, {'gp8', 'g20', 'g13', 'g30', 'g0', 'gp11', 'gp16', 'gp17', 'g12'}]

# %%
class Net(object):
    def __init__(self, nodelist=None):
        self.nodelist = nodelist
        self.quadment = set()

    def calMent(self, node_list):
        b = calQuad(node_list)
        # print(b)
        set_list = []
        for i in b:
            n_list = []
            for exp in i:
                n_list.append(exp.name)
            set_list.append(set(n_list))
        i = 0
        for s in set_list:
            if 0 < len(set(self.nodelist) & s) < len(set(self.nodelist)):
                self.quadment.add(i)
            i = i + 1
        
    # def __repr__(self):
    #     return str(self.nodelist)

    def todone(self):
        print('done')

    def toset(self):
        # netset = []
        n_set = set(self.nodelist)
        return n_set

# %%
net_exp = []
for net in nodelist:
    n_exp = Net(net)
    # n_exp.toset()
    net_exp.append(n_exp)
L = [0 ,0, 0, 0]
for net in net_exp:
    net.calMent(node_exp)
    print(net.quadment)
    if len(net.quadment) == 1:
        continue
    for i in net.quadment:
        L[i] += 1
print(L)

# %%
def cal_all(pop, net_exp):
    allgene = geneCoord(pop)
    N = len(allgene)
    L_all = np.zeros([N, 1])
    for i in range(N):
        gene_exp = allgene[i]
        L = cal_one(gene_exp, net_exp)
        L_all[i] = sum(L)
    print(L_all)

# %%
def cal_one(gene_exp, net_exp):
    node_exp = []

    for dict in gene_exp:
        n_exp = Node(**dict)
        n_exp.quad()
        node_exp.append(n_exp)
    # print(node_exp[1].rant)
    L = [0 ,0, 0, 0]
    for net in net_exp:
        net.calMent(node_exp)
        # print(net.quadment)
        if len(net.quadment) == 1:
            continue
        for i in net.quadment:
            L[i] += 1
    # print(L)
    return L

# %%
cal_all(pop, net_exp)

# %%
cal_one(gene_exp, net_exp)
# Out:
# [40, 40, 40, 40]
